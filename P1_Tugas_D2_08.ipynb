# %% [markdown]
# <a href="https://colab.research.google.com/github/jonitodev/pcvk26_8_joniyogakusuma/blob/main/P1_Tugas_D2_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Langkah 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# Langkah 2

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://awsimages.detik.net.id/community/media/visual/2026/07/24/foto-kucing-lucu-1784909317974.png?w=700&q=90"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                            #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #concatenate image
  cv2_imshow(final_frame)                           #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=700x230>

# %% [markdown]
# Langkah 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi X lebar = ", tinggi, "X", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi X lebar =  230 X 350
# <PIL.Image.Image image mode=RGB size=350x230>

# %% [markdown]
# Langkah 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x230>

# %% [markdown]
# PERTANYAAN PRAKTIKUM D2
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# Jawab: Karena bisa dijalankan di browser tanpa instalasi, serta menyediakan GPU/TPU gratis untuk pemrosesan citra.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
# Jawab:
# - NumPy: operasi array/matriks
# - Pandas: manipulasi data tabel
# - OpenCV (cv2): pengolahan citra
# - cv2_imshow: menampilkan gambar di Colab
# - skimage.io: membaca citra dari URL
# - skimage.transform: transformasi geometrik citra
# - PIL: membuka dan menyimpan file citra
# - Matplotlib: visualisasi data
#
# Tidak semua harus digunakan. Yang dipakai di sesi ini terutama NumPy, OpenCV, cv2_imshow, dan skimage.io.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan?
#
# Jawab: Kode itu memperkecil citra menjadi 50% dari ukuran asli. Jika tidak dilakukan, citra tetap ukuran asli sehingga tampil lebih besar dan lebih lambat diproses.
#
# 4. Perhatikan potongan kode progam berikut :
#
# for y in range (lebar)
#  image_3[int((tinggi)/2), y] = [255,255,255]
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Jawab: [255,255,255] adalah nilai warna putih (R, G, B semuanya maksimum).
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
#
# Jawab: Resolusi ditentukan oleh jumlah pixel. Resolusi tinggi berarti banyak pixel sehingga detail lebih jelas. Resolusi rendah berarti sedikit pixel sehingga gambar pecah/kurang tajam.

# %% [markdown]
# TUGAS PRAKTIKUM D2

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis VERTIKAL di tengah gambar
# Kita loop sepanjang 'tinggi' (sumbu x), dan ubah pixel di kolom tengah (lebar/2)
for x in range(tinggi):
  image_3[x, int(lebar/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi, lebar = image_3.shape[:2]

# Menggambar dua garis diagonal (X)
cv.line(image_3, (0, 0), (lebar, tinggi), (255, 255, 255))
cv.line(image_3, (0, tinggi), (lebar, 0), (255, 255, 255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis VERTIKAL di tengah gambar
tinggi,lebar = image_3.shape[:2]

# Kita batasi dari seperempat lebar (lebar/4) sampai setengah lebar (2*lebar/4)
for y in range(int(lebar/4), int(2* lebar / 4)):
  image_3[int(tinggi/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x230>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Ambil tinggi dan lebar
tinggi, lebar = image_3.shape[:2]

# Potong bagian tinggi tengah gambar (dari 1/3 sampai 2/3) dan potongan bagian lebar tengah gambar (dari 1/4 sampai 2/3) lalu ubah jadi putih
image_3[int(tinggi/3):int(2*tinggi/3), int(lebar/4):int(2*lebar/4)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=700x230>
